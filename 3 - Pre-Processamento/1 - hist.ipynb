# %% [markdown]
# # Histogramas da imagem
#
# O histograma de uma imagem é a distribuição da frequência dos níveis de cinza em relação ao número de amostras.
# Essa distribuição nos fonece informaçõe sobre a qualidade da imagem, principalmente no que diz respeito à intensidade luminosa e contraste

# %% [markdown]
#  Baixando

# %%
# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\windows\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\windows\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Requirement already satisfied: numpy in c:\users\windows\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\windows\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\windows\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# Importando as bibliotecas

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Leitura da Imagem

# %%
img = cv.imread("Cinza.jpg")

# %% [markdown]
# Mostrar a imagem

# %%
plt.imshow(img)

# %% [markdown]
# ### Função hist
#
# * FUNÇÃO HIST(img, Num1, Intervalo)
# * Entrada:
#                 1.Img = Imagem com a qual queremos trabalhar.
#                 2. Num1 = Número de elementos distintos que podem ser representados.
#                 3. Intervalo = Intervalo entre os elementos.
# * Saída: Gráfico representando o histograma da imagem
#
# ### Função ravel
# * Função RAVEL(array)
# * Entrada:
#             1. Img = Matriz de entrada, no caso a imagem. Os elementos em um são lidos na ordem especificada por ordem e empacotados como uma matriz 1-D.
#
# * Saída: retorna uma matriz plana contígua (matriz 1D com todos os elementos da matriz de entrada e com o mesmo tipo que ela).

# %%
plt.hist(img.ravel(), 256, [0, 256])
plt.show()
